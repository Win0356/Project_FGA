# %% [markdown]
# # Classification Customer Churn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !dir
# Out:
# sample_data  submit.csv  test.csv  train.csv

# %%
train = pd.read_csv("train.csv")

test = pd.read_csv("test.csv")

# %% [markdown]
# # Identifikasi Data

# %%
train.head()
# Out:
#   state  account_length      area_code international_plan voice_mail_plan  \
# 0    OH             107  area_code_415                 no             yes
# 1    NJ             137  area_code_415                 no              no
# 2    OH              84  area_code_408                yes              no
# 3    OK              75  area_code_415                yes              no
# 4    MA             121  area_code_510                 no             yes
#
#    number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                     26              161.6              123
# 1                      0              243.4              114
# 2                      0              299.4               71
# 3                      0              166.7              113
# 4                     24              218.2               88
#
#    total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 0             27.47              195.5              103             16.62
# ...

# %%
train.tail()
# Out:
#      state  account_length      area_code international_plan voice_mail_plan  \
# 4245    MT              83  area_code_415                 no              no
# 4246    WV              73  area_code_408                 no              no
# 4247    NC              75  area_code_408                 no              no
# 4248    HI              50  area_code_408                 no             yes
# 4249    VT              86  area_code_415                 no             yes
#
#       number_vmail_messages  total_day_minutes  total_day_calls  \
# 4245                      0              188.3               70
# 4246                      0              177.9               89
# 4247                      0              170.7              101
# 4248                     40              235.7              127
# 4249                     34              129.4              102
#
#       total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# ...

# %%
train.shape
# Out:
# (4250, 20)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4250 entries, 0 to 4249
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   state                          4250 non-null   object
#  1   account_length                 4250 non-null   int64
#  2   area_code                      4250 non-null   object
#  3   international_plan             4250 non-null   object
#  4   voice_mail_plan                4250 non-null   object
#  5   number_vmail_messages          4250 non-null   int64
#  6   total_day_minutes              4250 non-null   float64
#  7   total_day_calls                4250 non-null   int64
#  8   total_day_charge               4250 non-null   float64
#  9   total_eve_minutes              4250 non-null   float64
#  10  total_eve_calls                4250 non-null   int64
#  11  total_eve_charge               4250 non-null   float64
# ...

# %%
train.describe()
# Out:
#        account_length  number_vmail_messages  total_day_minutes  \
# count     4250.000000            4250.000000        4250.000000
# mean       100.236235               7.631765         180.259600
# std         39.698401              13.439882          54.012373
# min          1.000000               0.000000           0.000000
# 25%         73.000000               0.000000         143.325000
# 50%        100.000000               0.000000         180.450000
# 75%        127.000000              16.000000         216.200000
# max        243.000000              52.000000         351.500000
#
#        total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# count      4250.000000       4250.000000        4250.000000      4250.000000
# mean         99.907294         30.644682         200.173906       100.176471
# std          19.850817          9.182096          50.249518        19.908591
# min           0.000000          0.000000           0.000000         0.000000
# ...

# %%
train.isnull().sum()
# Out:
# state                            0
# account_length                   0
# area_code                        0
# international_plan               0
# voice_mail_plan                  0
# number_vmail_messages            0
# total_day_minutes                0
# total_day_calls                  0
# total_day_charge                 0
# total_eve_minutes                0
# total_eve_calls                  0
# total_eve_charge                 0
# total_night_minutes              0
# total_night_calls                0
# total_night_charge               0
# total_intl_minutes               0
# total_intl_calls                 0
# total_intl_charge                0
# number_customer_service_calls    0
# churn                            0
# dtype: int64

# %%
def bar_chart(column):
  count = train[column].value_counts()

  index = count.index 
  values = count.values 

  fig = plt.figure(figsize = (10,  5))
  plt.bar(index, values , color = "blue", width = 0.7)

  plt.show()

# %%
bar_chart("churn")

# %%
bar_chart("number_customer_service_calls")

# %%
fig, ax = plt.subplots(figsize = (10, 7))
ax.hist(train.account_length)
plt.show()

# %%
g = sns.catplot(data = train, kind = "bar", x = "churn", y = "account_length", palette = "dark" , height = 7)

# %%
g = sns.catplot(data = train, kind = "bar", x = "churn", y = "number_customer_service_calls", palette = "dark" , height = 7)

# %% [markdown]
# # Preprocessing Data

# %% [markdown]
# # Data Cleaning

# %%
train.shape
# Out:
# (4250, 20)

# %%
test.shape
# Out:
# (750, 20)

# %%
train.isnull().sum()
# Out:
# state                            0
# account_length                   0
# area_code                        0
# international_plan               0
# voice_mail_plan                  0
# number_vmail_messages            0
# total_day_minutes                0
# total_day_calls                  0
# total_day_charge                 0
# total_eve_minutes                0
# total_eve_calls                  0
# total_eve_charge                 0
# total_night_minutes              0
# total_night_calls                0
# total_night_charge               0
# total_intl_minutes               0
# total_intl_calls                 0
# total_intl_charge                0
# number_customer_service_calls    0
# churn                            0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# id                               0
# state                            0
# account_length                   0
# area_code                        0
# international_plan               0
# voice_mail_plan                  0
# number_vmail_messages            0
# total_day_minutes                0
# total_day_calls                  0
# total_day_charge                 0
# total_eve_minutes                0
# total_eve_calls                  0
# total_eve_charge                 0
# total_night_minutes              0
# total_night_calls                0
# total_night_charge               0
# total_intl_minutes               0
# total_intl_calls                 0
# total_intl_charge                0
# number_customer_service_calls    0
# dtype: int64

# %% [markdown]
# # Feature Encoding

# %% [markdown]
# # Convert Churn ke Number

# %%
train.head()
# Out:
#   state  account_length      area_code international_plan voice_mail_plan  \
# 0    OH             107  area_code_415                 no             yes
# 1    NJ             137  area_code_415                 no              no
# 2    OH              84  area_code_408                yes              no
# 3    OK              75  area_code_415                yes              no
# 4    MA             121  area_code_510                 no             yes
#
#    number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                     26              161.6              123
# 1                      0              243.4              114
# 2                      0              299.4               71
# 3                      0              166.7              113
# 4                     24              218.2               88
#
#    total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 0             27.47              195.5              103             16.62
# ...

# %%
churn_mapping = {'no' : 0, 'yes' : 1}
train['churn'] = train['churn'].map(churn_mapping)

# %% [markdown]
# # Feature Selection

# %%
train.head()
# Out:
#   state  account_length      area_code international_plan voice_mail_plan  \
# 0    OH             107  area_code_415                 no             yes
# 1    NJ             137  area_code_415                 no              no
# 2    OH              84  area_code_408                yes              no
# 3    OK              75  area_code_415                yes              no
# 4    MA             121  area_code_510                 no             yes
#
#    number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                     26              161.6              123
# 1                      0              243.4              114
# 2                      0              299.4               71
# 3                      0              166.7              113
# 4                     24              218.2               88
#
#    total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 0             27.47              195.5              103             16.62
# ...

# %%
train = train[['account_length', 'number_customer_service_calls', 'churn']]
train
# Out:
#       account_length  number_customer_service_calls  churn
# 0                107                              1      0
# 1                137                              0      0
# 2                 84                              2      0
# 3                 75                              3      0
# 4                121                              3      0
# ...              ...                            ...    ...
# 4245              83                              0      0
# 4246              73                              3      0
# 4247              75                              1      0
# 4248              50                              2      0
# 4249              86                              0      0
#
# [4250 rows x 3 columns]

# %%
test = test[['account_length', 'number_customer_service_calls']]
test
# Out:
#      account_length  number_customer_service_calls
# 0               128                              1
# 1               118                              0
# 2                62                              4
# 3                93                              3
# 4               174                              3
# ..              ...                            ...
# 745             130                              0
# 746              73                              3
# 747             152                              3
# 748              61                              1
# 749             109                              0
#
# [750 rows x 2 columns]

# %% [markdown]
# # Modelling

# %%
train.shape
# Out:
# (4250, 3)

# %%
test.shape
# Out:
# (750, 2)

# %%
train.head()
# Out:
#    account_length  number_customer_service_calls  churn
# 0             107                              1      0
# 1             137                              0      0
# 2              84                              2      0
# 3              75                              3      0
# 4             121                              3      0

# %%
test.head()
# Out:
#    account_length  number_customer_service_calls
# 0             128                              1
# 1             118                              0
# 2              62                              4
# 3              93                              3
# 4             174                              3

# %%
train.shape, test.shape
# Out:
# ((4250, 3), (750, 2))

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
train_data = train.drop("churn",axis = 1 )
target = train['churn']

# %%
k_fold = KFold(n_splits=5 , shuffle=True, random_state=0)

clf = GaussianNB()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.87411765 0.86470588 0.86705882 0.86352941 0.86235294]

# %%
score.mean()
# Out:
# 0.8663529411764707

# %%
k_fold = KFold(n_splits=5 , shuffle=True, random_state=0)

clf = DecisionTreeClassifier()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.86705882 0.84352941 0.86941176 0.85294118 0.85058824]

# %%
score.mean()
# Out:
# 0.8567058823529411

# %% [markdown]
# # Prediction

# %%
train.head()
train['churn'].value_counts()
# Out:
# 0    3652
# 1     598
# Name: churn, dtype: int64

# %%
test.head()
# Out:
#    account_length  number_customer_service_calls
# 0             128                              1
# 1             118                              0
# 2              62                              4
# 3              93                              3
# 4             174                              3

# %%
clf = GaussianNB()
clf.fit(train_data, target)
# Out:
# GaussianNB()

# %%
prediction = clf.predict(test)

# %%
df_test = pd.read_csv("test.csv")
submission = pd.DataFrame({
        "number_customer_service_calls": df_test["number_customer_service_calls"],
        "account_length": df_test["account_length"],
        "churn": prediction
    })
submission
# Out:
#      number_customer_service_calls  account_length  churn
# 0                                1             128      0
# 1                                0             118      0
# 2                                4              62      0
# 3                                3              93      0
# 4                                3             174      0
# ..                             ...             ...    ...
# 745                              0             130      0
# 746                              3              73      0
# 747                              3             152      0
# 748                              1              61      0
# 749                              0             109      0
#
# [750 rows x 3 columns]

# %%
submission.to_csv("submit.csv", index = False)

# %%
test['churn'] = submission['churn']
test['churn'].value_counts()
# Out:
# 0    729
# 1     21
# Name: churn, dtype: int64
